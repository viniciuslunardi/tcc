# %%
import pandas as pd

# %%
df = pd.read_excel('../cleaned_dataset_no_percentile_outliers.xlsx')
metrics_df = pd.read_excel('metrics.xlsx')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
tfidf = TfidfVectorizer(stop_words='english')

df['metrics_category'] = df['metrics_category'].fillna('')

tfidf_matrix = tfidf.fit_transform(df['metrics_category'])

print(tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 843 stored elements and shape (210, 11)>
#   Coords	Values
#   (0, 2)	0.36785397053467966
#   (0, 8)	0.36785397053467966
#   (0, 7)	0.36966296217652744
#   (0, 10)	0.49796474564810644
#   (0, 1)	0.5871518706520775
#   (1, 2)	0.42418718502608116
#   (1, 8)	0.42418718502608116
#   (1, 7)	0.42627320593045187
#   (1, 1)	0.6770683998128054
#   (2, 2)	0.447344385859723
#   (2, 8)	0.447344385859723
#   (2, 7)	0.44954428668958635
#   (2, 5)	0.6306155208875892
#   (3, 2)	0.42418718502608116
#   (3, 8)	0.42418718502608116
#   (3, 7)	0.42627320593045187
#   (3, 1)	0.6770683998128054
#   (4, 2)	0.7071067811865476
#   (4, 8)	0.7071067811865476
#   (5, 7)	0.3699830860833148
#   (5, 1)	0.5876603374717014
#   (5, 5)	0.5190079897759539
#   (5, 6)	0.49839597743524755
#   (6, 2)	0.3265586371122741
#   (6, 8)	0.3265586371122741
#   :	:
#   (204, 7)	0.4566690048444662
#   (204, 10)	0.6151686485002908
#   (205, 2)	0.38706000522671336
# ...

# %%
metrics_df['Categories'] = metrics_df['Categories'].fillna('')

tfidf_matrix_metrics = tfidf.fit_transform(metrics_df['Categories'])

print(tfidf_matrix_metrics)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 75 stored elements and shape (32, 7)>
#   Coords	Values
#   (0, 1)	0.7071067811865476
#   (0, 5)	0.7071067811865476
#   (1, 0)	0.5018701170971416
#   (1, 2)	0.5994598289687519
#   (1, 4)	0.4774141091052109
#   (1, 3)	0.40106117668621816
#   (2, 1)	0.48826176852921144
#   (2, 5)	0.48826176852921144
#   (2, 6)	0.7233262685575946
#   (3, 0)	0.724539705530115
#   (3, 4)	0.6892330629840201
#   (4, 1)	0.39561625485547414
#   (4, 5)	0.39561625485547414
#   (4, 4)	0.586078304404905
#   (4, 6)	0.586078304404905
#   (5, 1)	0.39561625485547414
#   (5, 5)	0.39561625485547414
#   (5, 4)	0.586078304404905
#   (5, 6)	0.586078304404905
#   (6, 2)	0.6930628169108426
#   (6, 3)	0.4636850968744675
#   (6, 6)	0.5519602003334331
#   (7, 1)	0.41726716818265613
#   (7, 5)	0.41726716818265613
#   (7, 4)	0.6181526451729505
#   :	:
#   (19, 2)	0.7026201367084394
#   (19, 3)	0.4700793033563008
#   (20, 1)	0.5308350337962793
# ...
