# %%
import pandas as pd

# %%
df = pd.read_excel('updated_dataset.xlsx')
df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp  \
# 0             17:34:49           1   Product manager     0 a 5
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5
# 2             20:50:58           3   Product manager     0 a 5
# 3             22:26:06           4       Team leader     6 a 9
# 4             19:07:11           5   Product manager     0 a 5
#
#           org_size    org_field        agile_methods use_metrics_planning  \
# 0     Microempresa      energia  ['Scrum', 'Kanban']             Métricas
# 1     Microempresa   Financeiro  ['Scrum', 'Kanban']             Métricas
# 2  Pequena empresa      Eventos            ['Scrum']                  NaN
# 3     Microempresa       gestão  ['Scrum', 'Kanban']             Métricas
# 4  Pequena empresa  Agronegocio  ['Scrum', 'Kanban']             Métricas
#
#   use_metrics_review use_metrics_weekly  ... metric_10 metric_11 metric_12  \
# 0                NaN           Métricas  ...       NaN       NaN       NaN
# 1           Métricas                NaN  ...       NaN       NaN       NaN
# 2           Métricas                NaN  ...       NaN       NaN       NaN
# 3                NaN                NaN  ...       NaN       NaN       NaN
# 4           Métricas                NaN  ...       NaN       NaN       NaN
#
#   metric_13 metric_14 metric_15 metric_16 metric_17 metric_18  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
#    agile_methods_split
# 0  ['Scrum', 'Kanban']
# 1  ['Scrum', 'Kanban']
# 2            ['Scrum']
# 3  ['Scrum', 'Kanban']
# 4  ['Scrum', 'Kanban']
#
# [5 rows x 34 columns]

# %%
df = df.drop(columns=['org_field', 'use_metrics_na', 'agile_methods_split'])
df = df.dropna(subset=['sanitized_metrics'])
df = df.fillna('')
df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp  \
# 0             17:34:49           1   Product manager     0 a 5
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5
# 2             20:50:58           3   Product manager     0 a 5
# 3             22:26:06           4       Team leader     6 a 9
# 4             19:07:11           5   Product manager     0 a 5
#
#           org_size        agile_methods use_metrics_planning  \
# 0     Microempresa  ['Scrum', 'Kanban']             Métricas
# 1     Microempresa  ['Scrum', 'Kanban']             Métricas
# 2  Pequena empresa            ['Scrum']
# 3     Microempresa  ['Scrum', 'Kanban']             Métricas
# 4  Pequena empresa  ['Scrum', 'Kanban']             Métricas
#
#   use_metrics_review use_metrics_weekly use_metrics_daily  ... metric_9  \
# 0                              Métricas                    ...
# 1           Métricas                                       ...
# 2           Métricas                                       ...
# 3                                                          ...
# 4           Métricas                                       ...
#
#   metric_10 metric_11 metric_12 metric_13 metric_14 metric_15 metric_16  \
# 0
# 1
# 2
# 3
# 4
#
#   metric_17 metric_18
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 31 columns]

# %%
columns_to_update = ['use_metrics_planning', 'use_metrics_review', 'use_metrics_weekly', 'use_metrics_daily', 'use_metrics_retro']

for column in columns_to_update:
    df[column] = df[column].apply(lambda x: 'Sim' if x == 'Métricas' else 'Não' if x == '' else x)

df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp  \
# 0             17:34:49           1   Product manager     0 a 5
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5
# 2             20:50:58           3   Product manager     0 a 5
# 3             22:26:06           4       Team leader     6 a 9
# 4             19:07:11           5   Product manager     0 a 5
#
#           org_size        agile_methods use_metrics_planning  \
# 0     Microempresa  ['Scrum', 'Kanban']                  Sim
# 1     Microempresa  ['Scrum', 'Kanban']                  Sim
# 2  Pequena empresa            ['Scrum']                  Não
# 3     Microempresa  ['Scrum', 'Kanban']                  Sim
# 4  Pequena empresa  ['Scrum', 'Kanban']                  Sim
#
#   use_metrics_review use_metrics_weekly use_metrics_daily  ... metric_9  \
# 0                Não                Sim               Não  ...
# 1                Sim                Não               Não  ...
# 2                Sim                Não               Não  ...
# 3                Não                Não               Não  ...
# 4                Sim                Não               Não  ...
#
#   metric_10 metric_11 metric_12 metric_13 metric_14 metric_15 metric_16  \
# 0
# 1
# 2
# 3
# 4
#
#   metric_17 metric_18
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 31 columns]

# %%
metrics_columns = [
    'metric_1', 'metric_2', 'metric_3', 'metric_4', 'metric_5', 'metric_6', 
    'metric_7', 'metric_8', 'metric_9', 'metric_10', 'metric_11', 'metric_12', 
    'metric_13', 'metric_14', 'metric_15', 'metric_16', 'metric_17', 'metric_18'
]

df = df.drop(columns=metrics_columns)
df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp  \
# 0             17:34:49           1   Product manager     0 a 5
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5
# 2             20:50:58           3   Product manager     0 a 5
# 3             22:26:06           4       Team leader     6 a 9
# 4             19:07:11           5   Product manager     0 a 5
#
#           org_size        agile_methods use_metrics_planning  \
# 0     Microempresa  ['Scrum', 'Kanban']                  Sim
# 1     Microempresa  ['Scrum', 'Kanban']                  Sim
# 2  Pequena empresa            ['Scrum']                  Não
# 3     Microempresa  ['Scrum', 'Kanban']                  Sim
# 4  Pequena empresa  ['Scrum', 'Kanban']                  Sim
#
#   use_metrics_review use_metrics_weekly use_metrics_daily use_metrics_retro  \
# 0                Não                Sim               Não               Não
# 1                Sim                Não               Não               Não
# 2                Sim                Não               Não               Sim
# 3                Não                Não               Não               Sim
# 4                Sim                Não               Não               Sim
#
#                                     metrics_category  \
# 0  Cronograma e progresso, Produto, Tecnologia, C...
# 1           Cronograma e progresso, Produto, Cliente
# 2           Cronograma e progresso, Pessoas, Produto
# 3           Cronograma e progresso, Produto, Cliente
# 4                             Cronograma e progresso
#
#                                    sanitized_metrics
# 0                                Ideal team capacity
# 1  NPS, Burndown, Outstanding bugs, Throughput, N...
# 2                            Burndown, OKR, Velocity
# 3               CAC, Throughput, Roadmaps, Conversão
# 4                             User Story Points, NPS

# %%
# Split the 'sanitized_metrics' column by comma and explode it into multiple rows
df = df.assign(sanitized_metrics=df['sanitized_metrics'].fillna('').str.split(', ')).explode('sanitized_metrics')

df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp      org_size  \
# 0             17:34:49           1   Product manager     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
#
#          agile_methods use_metrics_planning use_metrics_review  \
# 0  ['Scrum', 'Kanban']                  Sim                Não
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
#
#   use_metrics_weekly use_metrics_daily use_metrics_retro  \
# 0                Sim               Não               Não
# 1                Não               Não               Não
# 1                Não               Não               Não
# 1                Não               Não               Não
# 1                Não               Não               Não
#
#                                     metrics_category    sanitized_metrics
# 0  Cronograma e progresso, Produto, Tecnologia, C...  Ideal team capacity
# 1           Cronograma e progresso, Produto, Cliente                  NPS
# 1           Cronograma e progresso, Produto, Cliente             Burndown
# 1           Cronograma e progresso, Produto, Cliente     Outstanding bugs
# 1           Cronograma e progresso, Produto, Cliente           Throughput

# %%
# Preencher valores nulos com string vazia
df.dropna(inplace=True)

df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp      org_size  \
# 0             17:34:49           1   Product manager     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
#
#          agile_methods use_metrics_planning use_metrics_review  \
# 0  ['Scrum', 'Kanban']                  Sim                Não
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
#
#   use_metrics_weekly use_metrics_daily use_metrics_retro  \
# 0                Sim               Não               Não
# 1                Não               Não               Não
# 1                Não               Não               Não
# 1                Não               Não               Não
# 1                Não               Não               Não
#
#                                     metrics_category    sanitized_metrics
# 0  Cronograma e progresso, Produto, Tecnologia, C...  Ideal team capacity
# 1           Cronograma e progresso, Produto, Cliente                  NPS
# 1           Cronograma e progresso, Produto, Cliente             Burndown
# 1           Cronograma e progresso, Produto, Cliente     Outstanding bugs
# 1           Cronograma e progresso, Produto, Cliente           Throughput

# %%
# Lista de possíveis valores para agile_methods e metrics_category
agile_methods_list = ['Scrum', 'Kanban', 'ScrumBan', 'XP', 'Safe', 'Lean']  # Adicione os métodos ágeis utilizados
metrics_category_list = ['Cronograma e progresso', 'Produto', 'Processo', 'Tecnologia', 'Pessoas', 'Cliente']


# Função para verificar se um valor está presente na lista da coluna
def expand_column(df, column, values_list, prefix):
    for value in values_list:
        column_name = f'{prefix}_{value.lower().replace(" ", "_")}'
        df[column_name] = df[column].apply(lambda x: 'Sim' if value in str(x) else 'Não')
        # Verificar se a coluna foi criada corretamente
        if column_name not in df.columns:
            print(f"Erro: coluna {column_name} não foi criada.")
    return df

# Expandir a coluna agile_methods
df = expand_column(df, 'agile_methods', agile_methods_list, 'agile_methods')

# Expandir a coluna metrics_category
df = expand_column(df, 'metrics_category', metrics_category_list, 'metrics_category')

# Verificar as novas colunas criadas
df.head()
# Out:
#   Carimbo de data/hora  id_integer              role years_exp      org_size  \
# 0             17:34:49           1   Product manager     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
# 1             17:57:23           2  Desenvolvedor(a)     0 a 5  Microempresa
#
#          agile_methods use_metrics_planning use_metrics_review  \
# 0  ['Scrum', 'Kanban']                  Sim                Não
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
# 1  ['Scrum', 'Kanban']                  Sim                Sim
#
#   use_metrics_weekly use_metrics_daily  ... agile_methods_scrumban  \
# 0                Sim               Não  ...                    Não
# 1                Não               Não  ...                    Não
# 1                Não               Não  ...                    Não
# 1                Não               Não  ...                    Não
# 1                Não               Não  ...                    Não
#
#   agile_methods_xp agile_methods_safe agile_methods_lean  \
# 0              Não                Não                Não
# 1              Não                Não                Não
# 1              Não                Não                Não
# 1              Não                Não                Não
# 1              Não                Não                Não
#
#   metrics_category_cronograma_e_progresso metrics_category_produto  \
# 0                                     Sim                      Sim
# 1                                     Sim                      Sim
# 1                                     Sim                      Sim
# 1                                     Sim                      Sim
# 1                                     Sim                      Sim
#
#   metrics_category_processo metrics_category_tecnologia  \
# 0                       Não                         Sim
# 1                       Não                         Não
# 1                       Não                         Não
# 1                       Não                         Não
# 1                       Não                         Não
#
#   metrics_category_pessoas metrics_category_cliente
# 0                      Não                      Sim
# 1                      Não                      Sim
# 1                      Não                      Sim
# 1                      Não                      Sim
# 1                      Não                      Sim
#
# [5 rows x 25 columns]

# %%
df.to_excel('ready_for_filtering.xlsx', index=False)
