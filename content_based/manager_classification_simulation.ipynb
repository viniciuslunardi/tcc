# %%
import pandas as pd
import joblib

# %%
# Simulação de vários usuários com diferentes perfis
user_data = [
     {
        'role_Product manager': 1,
        'role_Desenvolvedor(a)': 0,
        'role_Team leader': 0,
        'role_Scrum master': 0,
        'role_Engineering Manager': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 1,
        'years_exp_6 a 9': 0,
        'years_exp_10 a 20': 0,
        'org_size_Microempresa': 1,
        'org_size_Pequena empresa': 0,
        'org_size_Grande empresa': 0,
        'use_metrics_planning': 1,
        'use_metrics_review': 0,
        'use_metrics_weekly': 1,
        'use_metrics_daily': 0,
        'use_metrics_retro': 1,
        'Scrum': 1,
        'Kanban': 1,
        'Lean': 0,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    },
    {
        'role_Product manager': 0,
        'role_Desenvolvedor(a)': 1,
        'role_Team leader': 0,
        'role_Scrum master': 0,
        'role_Engineering Manager': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 1,
        'years_exp_6 a 9': 0,
        'years_exp_10 a 20': 0,
        'org_size_Microempresa': 1,
        'org_size_Pequena empresa': 0,
        'org_size_Grande empresa': 0,
        'use_metrics_planning': 1,
        'use_metrics_review': 1,
        'use_metrics_weekly': 0,
        'use_metrics_daily': 0,
        'use_metrics_retro': 0,
        'Scrum': 1,
        'Kanban': 1,
        'Lean': 0,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    },
    {
        'role_Product manager': 1,
        'role_Desenvolvedor(a)': 0,
        'role_Team leader': 0,
        'role_Scrum master': 0,
        'role_Engineering Manager': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 1,
        'years_exp_6 a 9': 0,
        'years_exp_10 a 20': 0,
        'org_size_Microempresa': 0,
        'org_size_Pequena empresa': 1,
        'org_size_Grande empresa': 0,
        'use_metrics_planning': 0,
        'use_metrics_review': 1,
        'use_metrics_weekly': 0,
        'use_metrics_daily': 0,
        'use_metrics_retro': 1,
        'Scrum': 1,
        'Kanban': 0,
        'Lean': 0,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    },
    {
        'role_Product manager': 0,
        'role_Desenvolvedor(a)': 0,
        'role_Team leader': 1,
        'role_Scrum master': 0,
        'role_Engineering Manager': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 0,
        'years_exp_6 a 9': 1,
        'years_exp_10 a 20': 0,
        'org_size_Microempresa': 1,
        'org_size_Pequena empresa': 0,
        'org_size_Grande empresa': 0,
        'use_metrics_planning': 0,
        'use_metrics_review': 1,
        'use_metrics_weekly': 1,
        'use_metrics_daily': 1,
        'use_metrics_retro': 1,
        'Scrum': 1,
        'Kanban': 1,
        'Lean': 0,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    },
    {
        'role_Product manager': 1,
        'role_Desenvolvedor(a)': 0,
        'role_Team leader': 0,
        'role_Scrum master': 0,
        'role_Engineering Manager': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 1,
        'years_exp_6 a 9': 0,
        'years_exp_10 a 20': 0,
        'org_size_Microempresa': 0,
        'org_size_Pequena empresa': 1,
        'org_size_Grande empresa': 0,
        'use_metrics_planning': 0,
        'use_metrics_review': 1,
        'use_metrics_weekly': 1,
        'use_metrics_daily': 0,
        'use_metrics_retro': 1,
        'Scrum': 1,
        'Kanban': 1,
        'Lean': 0,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    },
        {
        'role_Engineering Manager': 1,
        'role_Team leader': 0,
        'role_Product manager': 0,
        'role_Desenvolvedor(a)': 0,
        'role_Scrum master': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 0,
        'years_exp_6 a 9': 0,
        'years_exp_10 a 20': 1,
        'years_exp_Mais de 20': 0,
        'org_size_Microempresa': 0,
        'org_size_Pequena empresa': 0,
        'org_size_Grande empresa': 1,
        'use_metrics_planning': 0,  # Não preenchido
        'use_metrics_review': 0,  # Não preenchido
        'use_metrics_weekly': 0,  # Não preenchido
        'use_metrics_daily': 0,  # Não preenchido
        'use_metrics_retro': 0,  # Gerenciamento de riscos
        'Scrum': 0,
        'Kanban': 1,
        'Lean': 1,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    },
    {
        'role_Engineering Manager': 0,
        'role_Team leader': 1,
        'role_Product manager': 0,
        'role_Desenvolvedor(a)': 0,
        'role_Scrum master': 0,
        'role_Project Manager': 0,
        'role_Technical leader': 0,
        'years_exp_0 a 5': 0,
        'years_exp_6 a 9': 0,
        'years_exp_10 a 20': 0,
        'years_exp_Mais de 20': 1,
        'org_size_Microempresa': 0,
        'org_size_Pequena empresa': 0,
        'org_size_Grande empresa': 1,
        'use_metrics_planning': 1,  # Gerenciamento de riscos, Métricas
        'use_metrics_review': 1,  # Gerenciamento de riscos, Métricas
        'use_metrics_weekly': 0,  # Não preenchido
        'use_metrics_daily': 1,  # Gerenciamento de riscos, Métricas
        'use_metrics_retro': 1,  # Gerenciamento de riscos, Métricas
        'Scrum': 1,
        'Kanban': 1,
        'Lean': 0,
        'XP': 0,
        'Safe': 0,
        'ScrumBan': 0
    }
]
# Transformar os dados de usuários em um DataFrame
user_df = pd.DataFrame(user_data)

# %%
# Carregar a estrutura de colunas salva durante o treinamento
column_structure = joblib.load('column_structure.joblib')

# %%
# Adicionar as colunas faltantes no user_df e preencher com 0
missing_cols = set(column_structure) - set(user_df.columns)
for col in missing_cols:
    user_df[col] = 0

# %%
# Reordenar as colunas para garantir que a ordem seja a mesma do treino
user_df = user_df[column_structure]

# %%
# Remover as colunas relacionadas às categorias de métricas (se presentes)
categories = ['Cronograma e progresso', 'Produto', 'Processo', 'Tecnologia', 'Pessoas', 'Cliente']
user_df = user_df.drop(columns=categories, errors='ignore')  # Remover categorias de métricas

# %%
# Verificar se os tipos de dados estão corretos (inteiros/floats)
user_df = user_df.astype(float)

# %%
# Prever as afinidades para cada usuário simulado
category_probabilities = {user_idx: {} for user_idx in range(len(user_df))}

# %%
user_classification = {user_idx: [] for user_idx in range(len(user_df))}  # Para armazenar as categorias com > 50% de afinidade

# %%
# Definir o threshold mínimo de afinidade para recomendação
threshold = 0.5

# %%
for category in categories:
    # Carregar o modelo treinado
    model_filename = f"modelo_{category}_ajustado.joblib"
    rf_binary = joblib.load(model_filename)
    
    # Prever as afinidades para todos os usuários
    user_affinities = rf_binary.predict_proba(user_df)[:, 1]
    
    # Armazenar as afinidades e classificar as métricas com afinidade > 50%
    for user_idx, affinity in enumerate(user_affinities):
        category_probabilities[user_idx][category] = affinity
        if affinity >= 0.5:
            user_classification[user_idx].append(category)  # Classificar se afinidade > 50%

# Exibir as probabilidades de afinidade para cada usuário e suas classificações
for user_idx, probabilities in category_probabilities.items():
    print(f"\nUsuário {user_idx + 1}:")
    for category, probability in probabilities.items():
        print(f"Afinidade para {category}: {probability:.2f}")
    
    # Exibir as categorias de métricas com afinidade > 50%
    if user_classification[user_idx]:
        print(f"Usuário {user_idx + 1} está classificado com as seguintes métricas (> 50% afinidade): {', '.join(user_classification[user_idx])}")
    else:
        print(f"Usuário {user_idx + 1} não tem afinidade acima de 50% para nenhuma métrica.")
# Out:
# Usuário 1:
# Afinidade para Cronograma e progresso: 0.60
# Afinidade para Produto: 0.14
# Afinidade para Processo: 0.09
# Afinidade para Tecnologia: 0.28
# Afinidade para Pessoas: 0.15
# Afinidade para Cliente: 0.46
# Usuário 1 está classificado com as seguintes métricas (> 50% afinidade): Cronograma e progresso
#
# Usuário 2:
# Afinidade para Cronograma e progresso: 0.88
# Afinidade para Produto: 0.27
# Afinidade para Processo: 0.13
# Afinidade para Tecnologia: 0.21
# Afinidade para Pessoas: 0.10
# Afinidade para Cliente: 0.15
# Usuário 2 está classificado com as seguintes métricas (> 50% afinidade): Cronograma e progresso
#
# Usuário 3:
# Afinidade para Cronograma e progresso: 0.48
# Afinidade para Produto: 0.35
# Afinidade para Processo: 0.02
# Afinidade para Tecnologia: 0.08
# Afinidade para Pessoas: 0.35
# Afinidade para Cliente: 0.01
# Usuário 3 não tem afinidade acima de 50% para nenhuma métrica.
#
# Usuário 4:
# Afinidade para Cronograma e progresso: 0.51
# Afinidade para Produto: 0.45
# Afinidade para Processo: 0.47
# Afinidade para Tecnologia: 0.30
# Afinidade para Pessoas: 0.14
# Afinidade para Cliente: 0.26
# Usuário 4 está classificado com as seguintes métricas (> 50% afinidade): Cronograma e progresso
#
# Usuário 5:
# Afinidade para Cronograma e progresso: 0.53
# Afinidade para Produto: 0.30
# Afinidade para Processo: 0.11
# Afinidade para Tecnologia: 0.16
# Afinidade para Pessoas: 0.39
# Afinidade para Cliente: 0.14
# Usuário 5 está classificado com as seguintes métricas (> 50% afinidade): Cronograma e progresso
#
# Usuário 6:
# Afinidade para Cronograma e progresso: 0.29
# Afinidade para Produto: 0.61
# Afinidade para Processo: 0.19
# Afinidade para Tecnologia: 0.38
# Afinidade para Pessoas: 0.94
# Afinidade para Cliente: 0.34
# Usuário 6 está classificado com as seguintes métricas (> 50% afinidade): Produto, Pessoas
#
# Usuário 7:
# Afinidade para Cronograma e progresso: 0.24
# Afinidade para Produto: 0.53
# Afinidade para Processo: 0.54
# Afinidade para Tecnologia: 0.10
# Afinidade para Pessoas: 0.05
# Afinidade para Cliente: 0.01
# Usuário 7 está classificado com as seguintes métricas (> 50% afinidade): Produto, Processo

# %%
metrics_data = pd.read_excel('extracted_metrics.xlsx', sheet_name="Extracted metrics")
metrics_data.head()
# Out:
#   Metric #                           Metric Name Source (primary study #)  \
# 0        1              Individual effectiveness                      S12
# 1        1                                   NaN                      S13
# 2        2    Weekly working hours of individual                      S12
# 3        3  Individual effective available hours                      S12
# 4        4               Individual Contribution                      S11
#
#         Name of metric by primary study  \
# 0              Individual effectiveness
# 1                Individual performance
# 2    Weekly working hours of individual
# 3  Individual effective available hours
# 4                          Contribution
#
#                                   Metric Description  \
# 0                                                n/i
# 1  Individual performance: contribution to value\...
# 2                                                n/i
# 3                                                n/i
# 4  Measures the direct participation and quality ...
#
#   Common Issue Area (PSM Classification) Translation
# 0                     Resources and Cost     Pessoas
# 1                     Resources and Cost     Pessoas
# 2                     Resources and Cost     Pessoas
# 3                     Resources and Cost     Pessoas
# 4                     Resources and Cost     Pessoas

# %%
category_to_metrics = metrics_data.groupby('Translation')['Metric Name'].apply(list).to_dict()

# %%
# Função para recomendar métricas com base nas afinidades das categorias
def recomendar_metricas_com_afinidade(category_probabilities, category_to_metrics, threshold):
    recommendations = {}
    for user_idx, category_affinities in category_probabilities.items():
        user_recommendations = []
        for categoria, afinidade in category_affinities.items():
            if categoria in category_to_metrics and afinidade >= threshold:
                # A afinidade de cada métrica é igual à afinidade da sua categoria
                for metrica in category_to_metrics[categoria]:
                    if pd.notna(metrica):  # Certificar-se de que a métrica não é 'nan'
                        user_recommendations.append((metrica, afinidade))
        
        # Ordenar métricas por afinidade (decrescente) para cada usuário
        user_recommendations.sort(key=lambda x: x[1], reverse=True)
        recommendations[user_idx] = user_recommendations
    
    return recommendations

# %%
# Exemplo de uso da função de recomendação:
metric_recommendations_with_affinity = recomendar_metricas_com_afinidade(category_probabilities, category_to_metrics, threshold)

# %%
# Exibir as recomendações de métricas para cada usuário, mostrando também as afinidades
for user_idx, metrics_with_affinity in metric_recommendations_with_affinity.items():
    print(f"\nRecomendações de Métricas para Usuário {user_idx + 1} (com afinidade >= {threshold}):")
    if metrics_with_affinity:
        for metric, affinity in metrics_with_affinity:
            print(f"- {metric} (Afinidade: {affinity:.2f})")
    else:
        print(f"Nenhuma métrica recomendada para o Usuário {user_idx + 1}.")
    print("-" * 40)
# Out:
# Recomendações de Métricas para Usuário 1 (com afinidade >= 0.5):
# - Number of completed tasks (Afinidade: 0.60)
# - Scope growth (Afinidade: 0.60)
# - Priority Shift (Afinidade: 0.60)
# - Rejected Product Backlog Items (Afinidade: 0.60)
# - Indicator about risky user stories (Afinidade: 0.60)
# - Reopened Tickets (Afinidade: 0.60)
# - Cumulative Flow Diagrams (Afinidade: 0.60)
# - Number of epics last sprint (Afinidade: 0.60)
# - WIP (work in progress) (Afinidade: 0.60)
# - WIP (work in progress) (Afinidade: 0.60)
# - Blocked tasks (Afinidade: 0.60)
# - Merge Request Life Time (Afinidade: 0.60)
# - Merge Request Review (Afinidade: 0.60)
# ----------------------------------------
#
# Recomendações de Métricas para Usuário 2 (com afinidade >= 0.5):
# - Number of completed tasks (Afinidade: 0.88)
# - Scope growth (Afinidade: 0.88)
# - Priority Shift (Afinidade: 0.88)
# - Rejected Product Backlog Items (Afinidade: 0.88)
# - Indicator about risky user stories (Afinidade: 0.88)
# - Reopened Tickets (Afinidade: 0.88)
# - Cumulative Flow Diagrams (Afinidade: 0.88)
# - Number of epics last sprint (Afinidade: 0.88)
# - WIP (work in progress) (Afinidade: 0.88)
# - WIP (work in progress) (Afinidade: 0.88)
# - Blocked tasks (Afinidade: 0.88)
# - Merge Request Life Time (Afinidade: 0.88)
# - Merge Request Review (Afinidade: 0.88)
# ----------------------------------------
#
# Recomendações de Métricas para Usuário 3 (com afinidade >= 0.5):
# Nenhuma métrica recomendada para o Usuário 3.
# ----------------------------------------
#
# Recomendações de Métricas para Usuário 4 (com afinidade >= 0.5):
# - Number of completed tasks (Afinidade: 0.51)
# - Scope growth (Afinidade: 0.51)
# - Priority Shift (Afinidade: 0.51)
# - Rejected Product Backlog Items (Afinidade: 0.51)
# - Indicator about risky user stories (Afinidade: 0.51)
# - Reopened Tickets (Afinidade: 0.51)
# - Cumulative Flow Diagrams (Afinidade: 0.51)
# - Number of epics last sprint (Afinidade: 0.51)
# - WIP (work in progress) (Afinidade: 0.51)
# - WIP (work in progress) (Afinidade: 0.51)
# - Blocked tasks (Afinidade: 0.51)
# - Merge Request Life Time (Afinidade: 0.51)
# - Merge Request Review (Afinidade: 0.51)
# ----------------------------------------
#
# Recomendações de Métricas para Usuário 5 (com afinidade >= 0.5):
# - Number of completed tasks (Afinidade: 0.53)
# - Scope growth (Afinidade: 0.53)
# - Priority Shift (Afinidade: 0.53)
# - Rejected Product Backlog Items (Afinidade: 0.53)
# - Indicator about risky user stories (Afinidade: 0.53)
# - Reopened Tickets (Afinidade: 0.53)
# - Cumulative Flow Diagrams (Afinidade: 0.53)
# - Number of epics last sprint (Afinidade: 0.53)
# - WIP (work in progress) (Afinidade: 0.53)
# - WIP (work in progress) (Afinidade: 0.53)
# - Blocked tasks (Afinidade: 0.53)
# - Merge Request Life Time (Afinidade: 0.53)
# - Merge Request Review (Afinidade: 0.53)
# ----------------------------------------
#
# Recomendações de Métricas para Usuário 6 (com afinidade >= 0.5):
# - Individual effectiveness (Afinidade: 0.94)
# - Weekly working hours of individual (Afinidade: 0.94)
# - Individual effective available hours (Afinidade: 0.94)
# - Individual Contribution (Afinidade: 0.94)
# - Individual Influence (Afinidade: 0.94)
# - Individual Impact (Afinidade: 0.94)
# - Individual Impression (Afinidade: 0.94)
# - Effort remaining (Afinidade: 0.94)
# - Effort (Afinidade: 0.94)
# - Team total available hours (Afinidade: 0.94)
# - Team total effective available hours (Afinidade: 0.94)
# - Planned hours (Afinidade: 0.94)
# - Number of Sprints (Afinidade: 0.94)
# - Sprint duration (Afinidade: 0.94)
# - Effort estimation accuracy (Afinidade: 0.94)
# - User Story Points (Afinidade: 0.94)
# - Number of remaining tasks (Afinidade: 0.94)
# - Backlog size (Afinidade: 0.94)
# - Cost Devitation (Afinidade: 0.94)
# - Earned Business Value (Afinidade: 0.94)
# - Number of Projects (n) (Afinidade: 0.94)
# - Project size (Afinidade: 0.94)
# - Project avg. cost (Afinidade: 0.94)
# - Estimation of user stories (Afinidade: 0.94)
# - Pairing Frequency (Afinidade: 0.94)
# - Number of members per team (Afinidade: 0.94)
# - Role Time Measure (RTM). (Afinidade: 0.94)
# - Role Communication Measure (RCM) (Afinidade: 0.94)
# - Role Management Measure (RMM) (Afinidade: 0.94)
# - Ideal team capacity (Afinidade: 0.94)
# - Non-working days (Afinidade: 0.94)
# - Cost model (CM) (Afinidade: 0.94)
# - Team and individual motivational (Afinidade: 0.94)
# - Number of change team members (Afinidade: 0.94)
# - ROI (Afinidade: 0.94)
# - Number of Active Customers (Afinidade: 0.94)
# - Team adaptability (Afinidade: 0.94)
# - Team Innovation (Afinidade: 0.94)
# - Effort spent outside sprint (Afinidade: 0.94)
# - Outstanding bugs (Afinidade: 0.61)
# - Critical bugs (Afinidade: 0.61)
# - Known bugs (Afinidade: 0.61)
# - Project avg. time-to-market (Afinidade: 0.61)
# - Delivery on time (Afinidade: 0.61)
# - Lead Time (Afinidade: 0.61)
# - Delivery to customer (Afinidade: 0.61)
# - Changed Product Backlog Items (Afinidade: 0.61)
# - Technical debt (Afinidade: 0.61)
# - Throughput (Afinidade: 0.61)
# - Velocity (Afinidade: 0.61)
# - Velocity (Afinidade: 0.61)
# - Velocity Deviation (Afinidade: 0.61)
# - Burndown (Afinidade: 0.61)
# - Quality rating (Afinidade: 0.61)
# - Number of deployments (Afinidade: 0.61)
# - Number of commits (Afinidade: 0.61)
# - Number of builds (Afinidade: 0.61)
# - Build time (Afinidade: 0.61)
# - Number of Attributes (NOA) (Afinidade: 0.61)
# - Number of Method (NOM) (Afinidade: 0.61)
# - Number of Parameters (NOP) (Afinidade: 0.61)
# - Depth Inheritance Tree (DIT) (Afinidade: 0.61)
# - Number of Children (NOC) (Afinidade: 0.61)
# - Response for a Class (RFC) (Afinidade: 0.61)
# - Lack of Cohesion of Methods (LCOM) (Afinidade: 0.61)
# - Cohesion Among Methods (CAM) (Afinidade: 0.61)
# - Access to Foreign Data (ATFD) (Afinidade: 0.61)
# - Tight Class Cohesion (TCC) (Afinidade: 0.61)
# - Number of code lines (Afinidade: 0.61)
# - Number of Name-Parts of a method (NNP) (Afinidade: 0.61)
# - Number of Characters (NC) (Afinidade: 0.61)
# - Number of Comment-
# Lines (CL) (Afinidade: 0.61)
# - Number of Local Variables (NLV) (Afinidade: 0.61)
# - Number of Created Objects (NCO) (Afinidade: 0.61)
# - Number of
# Referring Objects (NRO) (Afinidade: 0.61)
# - Class-level (Coupling between Objects,
# Number of Children, Depth of Inheritance Tree) (Afinidade: 0.61)
# - Number of Referring Objects (NRO) (Afinidade: 0.61)
# - Package-level (Cycle Count of
# Dependency Graph) (Afinidade: 0.61)
# - Requirements clarity index (Afinidade: 0.61)
# - Bugs density (Afinidade: 0.61)
# - Code Scanning (security) (Afinidade: 0.61)
# - Detection Rate (security) (Afinidade: 0.61)
# - Collective Code Ownership (Afinidade: 0.61)
# - Fan-In (Afinidade: 0.61)
# - Weighted Fan-In (Afinidade: 0.61)
# - Fan-Out (Afinidade: 0.61)
# - Weighted Fan-Out (Afinidade: 0.61)
# - Reach effciency In (Afinidade: 0.61)
# - Reach Effciency Out (Afinidade: 0.61)
# - Weak Components (Afinidade: 0.61)
# - Closeness-In (Afinidade: 0.61)
# - Closeness-Out (Afinidade: 0.61)
# - Purchased delivery units quantity (Afinidade: 0.61)
# - Technical Efficiency (Afinidade: 0.61)
# - Weighted Methods per Class (Afinidade: 0.61)
# ----------------------------------------
#
# Recomendações de Métricas para Usuário 7 (com afinidade >= 0.5):
# - Tasks attributes Quality (Afinidade: 0.54)
# - Number of development tasks without estimation of effort ("estimated") (Afinidade: 0.54)
# - Number of development tasks without real effort ("spend") (Afinidade: 0.54)
# - Fixed bugs (Afinidade: 0.54)
# - Hours spent on bugs (Afinidade: 0.54)
# - Time to fix (Afinidade: 0.54)
# - Hours spent on task (Afinidade: 0.54)
# - Cycle Time (Afinidade: 0.54)
# - Total points by use case (Afinidade: 0.54)
# - Queue impediments size (Afinidade: 0.54)
# - Downstream Impact (Afinidade: 0.54)
# - Code changes during sprint (Afinidade: 0.54)
# - Scrum teams (S) (Afinidade: 0.54)
# - Inspection Frequency (Afinidade: 0.54)
# - Flow efficiency (Afinidade: 0.54)
# - Time in meeting (Afinidade: 0.54)
# - Focus factor (Afinidade: 0.54)
# - Outstanding bugs (Afinidade: 0.53)
# - Critical bugs (Afinidade: 0.53)
# - Known bugs (Afinidade: 0.53)
# - Project avg. time-to-market (Afinidade: 0.53)
# - Delivery on time (Afinidade: 0.53)
# - Lead Time (Afinidade: 0.53)
# - Delivery to customer (Afinidade: 0.53)
# - Changed Product Backlog Items (Afinidade: 0.53)
# - Technical debt (Afinidade: 0.53)
# - Throughput (Afinidade: 0.53)
# - Velocity (Afinidade: 0.53)
# - Velocity (Afinidade: 0.53)
# - Velocity Deviation (Afinidade: 0.53)
# - Burndown (Afinidade: 0.53)
# - Quality rating (Afinidade: 0.53)
# - Number of deployments (Afinidade: 0.53)
# - Number of commits (Afinidade: 0.53)
# - Number of builds (Afinidade: 0.53)
# - Build time (Afinidade: 0.53)
# - Number of Attributes (NOA) (Afinidade: 0.53)
# - Number of Method (NOM) (Afinidade: 0.53)
# - Number of Parameters (NOP) (Afinidade: 0.53)
# - Depth Inheritance Tree (DIT) (Afinidade: 0.53)
# - Number of Children (NOC) (Afinidade: 0.53)
# - Response for a Class (RFC) (Afinidade: 0.53)
# - Lack of Cohesion of Methods (LCOM) (Afinidade: 0.53)
# - Cohesion Among Methods (CAM) (Afinidade: 0.53)
# - Access to Foreign Data (ATFD) (Afinidade: 0.53)
# - Tight Class Cohesion (TCC) (Afinidade: 0.53)
# - Number of code lines (Afinidade: 0.53)
# - Number of Name-Parts of a method (NNP) (Afinidade: 0.53)
# - Number of Characters (NC) (Afinidade: 0.53)
# - Number of Comment-
# Lines (CL) (Afinidade: 0.53)
# - Number of Local Variables (NLV) (Afinidade: 0.53)
# - Number of Created Objects (NCO) (Afinidade: 0.53)
# - Number of
# Referring Objects (NRO) (Afinidade: 0.53)
# - Class-level (Coupling between Objects,
# Number of Children, Depth of Inheritance Tree) (Afinidade: 0.53)
# - Number of Referring Objects (NRO) (Afinidade: 0.53)
# - Package-level (Cycle Count of
# Dependency Graph) (Afinidade: 0.53)
# - Requirements clarity index (Afinidade: 0.53)
# - Bugs density (Afinidade: 0.53)
# - Code Scanning (security) (Afinidade: 0.53)
# - Detection Rate (security) (Afinidade: 0.53)
# - Collective Code Ownership (Afinidade: 0.53)
# - Fan-In (Afinidade: 0.53)
# - Weighted Fan-In (Afinidade: 0.53)
# - Fan-Out (Afinidade: 0.53)
# - Weighted Fan-Out (Afinidade: 0.53)
# - Reach effciency In (Afinidade: 0.53)
# - Reach Effciency Out (Afinidade: 0.53)
# - Weak Components (Afinidade: 0.53)
# - Closeness-In (Afinidade: 0.53)
# - Closeness-Out (Afinidade: 0.53)
# - Purchased delivery units quantity (Afinidade: 0.53)
# - Technical Efficiency (Afinidade: 0.53)
# - Weighted Methods per Class (Afinidade: 0.53)
# ----------------------------------------
